# %%
from astropy.table import Table
catalog = Table.read("../stacked/data/24307.parquet")
catalog.info()
# Out:
# <Table length=6639772>
#                   name                    dtype
# ---------------------------------------- -------
#                                  halo_id   int64
#                                galaxy_id   int64
#                                     kind    int8
#                                   ra_gal float32
#                                  dec_gal float32
#                               ra_mag_gal float32
#                              dec_mag_gal float32
#                                    kappa float32
#                                   gamma1 float32
#                                   gamma2 float32
#                                    defl1 float32
#                                    defl2 float32
#                        true_redshift_gal float32
#                    observed_redshift_gal float32
#                        rproj_gal_in_halo float32
#                               color_kind    int8
#                            conc_vir_halo float32
# ...
